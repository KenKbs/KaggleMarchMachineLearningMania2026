# %% [markdown]
# # Progression checker
#
# ## Features
# - Basic features
# - Elo system (basic)
# - H2H history
#
# ## Models
# - LR model
#
# ## Results
# | Model    | Features         | pooled brier | men_brier 2022-2025 | women_brier 2022-2025 | best_params_men |
# |----------|------------------|--------------|---------------------|------------------------|-----------|
# | LR-model | Basic - no elo    | ?            | 0.19618504302135759 | 0.13855612829873767    | l1, c= 0.0186390122 |
# | LR-model | Basic with elo | 0.165468 | 0.194407 | 0.136529 | l1, c=0.0285267149 |
# | LR-model | Basic w. elo & H2H | 0.165237 | 0.194411 | 0.136063 | l1, c= 0.0294986645 |
